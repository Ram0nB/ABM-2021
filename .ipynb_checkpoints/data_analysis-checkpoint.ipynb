# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from os import listdir
from os.path import isfile, join
import ineqpy
DATA_dir = "sugarscape/data/"

# %%
data_filenames = [f for f in listdir(DATA_dir) if isfile(join(DATA_dir, f))]
print(data_filenames)
# Out:
# ['2021-01-20 15.19 Agent Vars.csv']

# %%
df_concat_list = []
run = 0
for data_filename in data_filenames:
    df = pd.read_csv(DATA_dir + data_filename)
    df.insert(0, "Run", run)
    run += 1
    
    for step in set(df["Step"].tolist()):
        wealth = np.array( df.loc[(df.Step == step)]["Wealth"].tolist() )
        gini = ineqpy.gini(np.array(wealth))
        df.loc[(df.Step == step), "Gini"] = gini
        
    df_concat_list.append(df)

data_raw = pd.concat(df_concat_list)
del df_concat_list
del run
data_raw
# Out:
#       Run  Step AgentID       Wealth  Position  Vision  N_Agents  Size  \
# 0       0     0       0     5.000000  (87, 67)       1        20    99
# 1       0     0       1     5.000000  (89, 83)       1        20    99
# 2       0     0       2     5.000000  (39, 69)       1        20    99
# 3       0     0       3     5.000000   (12, 1)       1        20    99
# 4       0     0       4     5.000000  (39, 50)       1        20    99
# ...   ...   ...     ...          ...       ...     ...       ...   ...
# 3340    0   299     4-3   418.219952  (37, 53)       1        20    99
# 3341    0   299    14-3  2486.219952   (61, 9)       1        20    99
# 3342    0   299    12-3   598.219952  (38, 13)       1        20    99
# 3343    0   299     0-3    22.887563  (88, 67)       1        20    99
# 3344    0   299     8-3  7139.219952  (60, 35)       1        20    99
#
#      tax brackets tax percentages inheritance taxbrackets  \
# 0          [0, 0]          [0, 0]    [0, 10, 30, 50, 100]
# 1          [0, 0]          [0, 0]    [0, 10, 30, 50, 100]
# 2          [0, 0]          [0, 0]    [0, 10, 30, 50, 100]
# 3          [0, 0]          [0, 0]    [0, 10, 30, 50, 100]
# 4          [0, 0]          [0, 0]    [0, 10, 30, 50, 100]
# ...           ...             ...                     ...
# 3340       [0, 0]          [0, 0]    [0, 10, 30, 50, 100]
# 3341       [0, 0]          [0, 0]    [0, 10, 30, 50, 100]
# 3342       [0, 0]          [0, 0]    [0, 10, 30, 50, 100]
# 3343       [0, 0]          [0, 0]    [0, 10, 30, 50, 100]
# 3344       [0, 0]          [0, 0]    [0, 10, 30, 50, 100]
#
#      inheritance tax percentages  Starting Wealth          Gini
# 0       [0, 0.3, 0.3, 0.35, 0.6]                5  2.594937e-32
# 1       [0, 0.3, 0.3, 0.35, 0.6]                5  2.594937e-32
# 2       [0, 0.3, 0.3, 0.35, 0.6]                5  2.594937e-32
# 3       [0, 0.3, 0.3, 0.35, 0.6]                5  2.594937e-32
# 4       [0, 0.3, 0.3, 0.35, 0.6]                5  2.594937e-32
# ...                          ...              ...           ...
# 3340    [0, 0.3, 0.3, 0.35, 0.6]                5  6.049320e-01
# 3341    [0, 0.3, 0.3, 0.35, 0.6]                5  6.049320e-01
# 3342    [0, 0.3, 0.3, 0.35, 0.6]                5  6.049320e-01
# 3343    [0, 0.3, 0.3, 0.35, 0.6]                5  6.049320e-01
# 3344    [0, 0.3, 0.3, 0.35, 0.6]                5  6.049320e-01
#
# [3345 rows x 14 columns]

# %%
data = data_raw.groupby(["Run", "Step"]).mean().reset_index()
data = data[["Run", "Step", "Gini"]]
data
# Out:
#      Run  Step          Gini
# 0      0     0  2.594937e-32
# 1      0     1  2.147708e-01
# 2      0     2  3.983022e-01
# 3      0     3  5.061166e-01
# 4      0     4  6.097449e-01
# ..   ...   ...           ...
# 295    0   295  6.050911e-01
# 296    0   296  6.051689e-01
# 297    0   297  6.050110e-01
# 298    0   298  6.050885e-01
# 299    0   299  6.049320e-01
#
# [300 rows x 3 columns]

# %%
plt.plot(data["Gini"].tolist())
plt.show()
